# %% [markdown]
# # Python While Loops

# %% [markdown]
# Python Loops
# Python has two primitive loop commands:
#
# *   while loops
# *   for loops

# %% [markdown]
# ## The while Loop
#
# With the while loop we can execute a set of statements as long as a condition is true.

# %%
# Print i as long as i is less than 6:

i = 1

while i < 6:
    i += 1 
    print(i)
# Note the output because the increment came before the print statement
# Note: In the output, because of the i += 1, the result can be said be an increase in 1 to all the values in the result.
# Because the i += 1 came before the print statement for i.
# So, in other words, the output which normally ought to 1,2,3,4,5
# But because of the i += 1, an extra +1 is automatically added to the initial result transforming it to 2,3,4,5,6.
# Out:
# 2
# 3
# 4
# 5
# 6

# %%
i = 1

while i < 6:
  print(i)
  i += 1
# Note the output because the print statement came before the increment
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# `Note: remember to increment i, or else the loop will continue forever.`
#
# The while loop requires relevant variables to be ready, in two examples above, we needed to define an indexing variable, i, which we set to 1.

# %% [markdown]
# ## The break Statement
#
# With the break statement we can stop the loop even if the while condition is true:

# %%
# Exit the loop when i is 3:

i = 1

while i < 6:
  print(i)
  if i == 3:
    break
  i += 1
# Out:
# 1
# 2
# 3

# %% [markdown]
# ## The continue Statement
#
# With the `continue statement we can stop the current iteration, and continue with the next`:

# %%
i = 0

while i < 6:
  i += 1
  if i == 3:
    continue
  print(i)

# Note that number 3 is missing in the result
# Out:
# 1
# 2
# 4
# 5
# 6

# %% [markdown]
# The else Statement
#
# With the else statement we can run a block of code once when the condition no longer is true:

# %%
# Print a message once the condition is false:

i = 1

while i < 6:
  print(i)
  i += 1
else:
  print("i is no longer less than 6")
# Out:
# 1
# 2
# 3
# 4
# 5
# i is no longer less than 6
