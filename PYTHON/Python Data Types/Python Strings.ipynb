# %% [markdown]
# # Python Strings
#
# ## Strings
#
# What is a String?
#
# A string is a sequence of characters enclosed inside quotation marks. The characters can include:
#
# - Letters
#
# - Numbers
#
# - Spaces
#
# - Symbols
#
# - Emojis
#
# - Special characters
#
# In Python, strings are one of the most frequently used data types because almost every program works with text.
#
# Strings in python are surrounded by either single quotation marks, or double quotation marks.
#
# 'hello' is the same as "hello".
#
# You can display a string literal with the print() function:

# %%
# Example

print("Hello")
print('Hello')
# Out:
# Hello
# Hello

# %% [markdown]
# ## Quotes Inside Quotes
#
# You can use quotes inside a string, as long as they don't match the quotes surrounding the string:

# %%
# Example

print("It's alright")
print("He is called 'Johnny'")
print('He is called "Johnny"')
# Out:
# It's alright
# He is called 'Johnny'
# He is called "Johnny"

# %% [markdown]
# # Assign String to a Variable
#
# Assigning a string to a variable is done with the variable name followed by an equal sign and the string:

# %%
# Example

a = "Hello"
print(a)
# Out:
# Hello

# %% [markdown]
# # Multiline Strings
#
# You can assign a multiline string to a variable by using three quotes:

# %%
# Example

# You can use three double quotes:

a = """Lorem ipsum dolor sit amet,
consectetur adipiscing elit,
sed do eiusmod tempor incididunt
ut labore et dolore magna aliqua."""
print(a)
# Out:
# Lorem ipsum dolor sit amet,
# consectetur adipiscing elit,
# sed do eiusmod tempor incididunt
# ut labore et dolore magna aliqua.

# %% [markdown]
# ### Or three single quotes:

# %%
# Example

a = '''Lorem ipsum dolor sit amet,
consectetur adipiscing elit,
sed do eiusmod tempor incididunt
ut labore et dolore magna aliqua.'''
print(a)
# Out:
# Lorem ipsum dolor sit amet,
# consectetur adipiscing elit,
# sed do eiusmod tempor incididunt
# ut labore et dolore magna aliqua.

# %%
a = 'Segun\'s car'
b = 'It\'s raining'
print(a)
print(b)
# Out:
# Segun's car
# It's raining

# %% [markdown]
# - Note: in the result, the line breaks are inserted at the same position as in the code.

# %% [markdown]
# ## Strings are Arrays
#
# Like many other popular programming languages, strings in Python are arrays of bytes representing unicode characters.
#
# However, Python does not have a character data type, a single character is simply a string with a length of 1.
#
# Square brackets can be used to access elements of the string.

# %%
# Example

# Get the character at position 1 (remember that the first character has the position 0):

a = "Hello, World!"
b = a[7]
print(b)
# Out:
# W

# %% [markdown]
# Looping Through a String
#
# Since strings are arrays, we can loop through the characters in a string, with a for loop.

# %% [markdown]
# `An array in Python is a data structure used to store an ordered collection of items where every element must be of the same data type.`

# %%
# Example

# Loop through the letters in the word "banana":

for x in "banana":
  print(x)
# Out:
# b
# a
# n
# a
# n
# a

# %% [markdown]
# ## String Length
#
# To get the length of a string, use the len() function.

# %%
# Example

# The len() function returns the length of a string:

a = "Hello, World!"
print(len(a))
# Out:
# 13

# %% [markdown]
# ## Check String
#
# To check if a certain phrase or character is present in a string, we can use the keyword in.

# %%
# Example

# Check if "free" is present in the following text:

txt = "The best things in life are free!"
print("life" in txt)
# Out:
# True

# %% [markdown]
# # Use it in an if statement:

# %%
# Example
# Print only if "free" is present:

txt = "The best things in life are free!"
if "free" in txt:
  print("Yes, 'free' is present.")
# Out:
# Yes, 'free' is present.

# %% [markdown]
# ## Check if NOT
#
# To check if a certain phrase or character is NOT present in a string, we can use the keyword not in.

# %%
# Example

# Check if "expensive" is NOT present in the following text:

txt = "The best things in life are free!"
print("expensive" not in txt)
# Out:
# True

# %% [markdown]
# ## Use it in an if statement:

# %%
# Example

# print only if "expensive" is NOT present:

txt = "The best things in life are free!"
if "expensive" not in txt:
  print("No, 'expensive' is NOT present.")
# Out:
# No, 'expensive' is NOT present.

# %% [markdown]
# ## Python - Slicing Strings

# %% [markdown]
# ### Slicing
#
# You can return a range of characters by using the slice syntax.
#
# Specify the start index and the end index, separated by a colon, to return a part of the string.

# %%
# Example

# Get the characters from position 2 to position 5 (not included):

b = "Hello, World!"
print(b[2:5])
# Out:
# llo

# %% [markdown]
# - Note: The first character has index 0.

# %% [markdown]
# ## Slice From the Start
#
# By leaving out the start index, the range will start at the first character:

# %%
# Example

# Get the characters from the start to position 5 (not included):

b = "Hello, World!"
print(b[:5])
# Out:
# Hello

# %% [markdown]
# ## Slice To the End
#
# By leaving out the end index, the range will go to the end:

# %%
# Example

# Get the characters from position 2, and all the way to the end:

b = "Hello, World!"
print(b[2:])
# Out:
# llo, World!

# %% [markdown]
# ## Negative Indexing
#
# Use negative indexes to start the slice from the end of the string:

# %%
# Example

# Get the characters:

# From: "o" in "World!" (position -5)

# To, but not included: "d" in "World!" (position -2):

b = "Hello, World!"
print(b[-5:-2])
# Out:
# orl

# %% [markdown]
# ## Python - Modify Strings
#
# Python has a set of built-in methods that you can use on strings.

# %% [markdown]
# ### Upper Case

# %%
# Example

# The upper() method returns the string in upper case:

a = "Hello, World!"
print(a.upper())
# Out:
# HELLO, WORLD!

# %% [markdown]
# ### Lower Case

# %%
# Example

# The lower() method returns the string in lower case:

a = "Hello, World!"
print(a.lower())
# Out:
# hello, world!

# %% [markdown]
# ### Remove Whitespace
#
# Whitespace is the space before and/or after the actual text, and very often you want to remove this space.

# %%
# Example

# The strip() method removes any whitespace from the beginning or the end:

a = " Hello, World! "
b = a.strip()
print(a) # returns the first " Hello World! " with white spaces
print(b) # returns "Hello, World!"
# Out:
#  Hello, World!
# Hello, World!

# %% [markdown]
# ## Replace String

# %%
# Example

# The replace() method replaces a string with another string:

a = "Hello, World!"
print(a.replace("H", "J"))
# Out:
# Jello, World!

# %% [markdown]
# ### Split String
#
# The split() method returns a list where the text between the specified separator becomes the list items.

# %%
# Example

# The split() method splits the string into substrings if it finds instances of the separator:

a = "Hello, World!"
print(a.split(",")) # returns ['Hello', ' World!']
# Out:
# ['Hello', ' World!']

# %%
full_name = "James Brown"
print(full_name.split(" "))
# Out:
# ['James', 'Brown']

# %% [markdown]
# ## Python - String Concatenation
#
# ### String Concatenation
#
# To concatenate, or combine, two strings you can use the + operator.

# %%
# Example

# Merge variable a with variable b into variable c:

a = "Hello"
b = "World"
c = a + b
print(c)
# Out:
# HelloWorld

# %%
# Example

# To add a space between them, add a " ":

a = "Hello"
b = "World"
c = a + " " + b
print(c)
# Out:
# Hello World

# %% [markdown]
# ## Python - Format - Strings
#
# ### String Format
#
# As we learned in the Python previously, we cannot combine strings and numbers like this:

# %%
# Example

age = 36
txt = "My name is John, I am " + age
print(txt)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[52], line 4
#       1 # Example
#       3 age = 36
# ----> 4 txt = "My name is John, I am " + age
#       5 print(txt)
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# **But we can combine strings and numbers by using f-strings or the format() method!**

# %% [markdown]
# ## F-Strings
#
# F-String was introduced in Python 3.6, and is now the preferred way of formatting strings.
#
# To specify a string as an f-string, simply put an f in front of the string literal, and add curly brackets {} as placeholders for variables and other operations.

# %%
# Example

# Create an f-string:

age = 36
txt = f"My name is John, I am {age}"
print(txt)
# Out:
# My name is John, I am 36

# %% [markdown]
# ## Placeholders and Modifiers
#
# A placeholder can contain variables, operations, functions, and modifiers to format the value.

# %%
# Example

# Add a placeholder for the price variable:

price = 59
txt = f"The price is {price} dollars"
print(txt)
# Out:
# The price is 59 dollars

# %% [markdown]
# ### A placeholder can include a modifier to format the value.
#
# A modifier is included by adding a colon : followed by a legal formatting type, like .2f which means fixed point number with 2 decimals:

# %%
# Example

# Display the price with 2 decimals:

price = 72.65978
txt = f"The price is {price:.2f} dollars"
print(txt)
# Out:
# The price is 72.66 dollars

# %% [markdown]
# ### A placeholder can contain Python code, like math operations:

# %%
# Example

# Perform a math operation in the placeholder, and return the result:

txt = f"The price is {20 * 59} dollars"
print(txt)
# Out:
# The price is 1180 dollars

# %% [markdown]
# ## Task 1 : Using formatted string, give an output like this : `Jack is 28 years old and he has an available balance of 100,000 naira.`

# %%
name = "Jack"
age = 28
available_balance = 100000

print(f"{name} is {age} years old and he has an available balance of {available_balance:,} naira.")
# Out:
# Jack is 28 years old and he has an available balance of 100,000 naira.

# %% [markdown]
# ## Task 2: Using formatted string, give an output like this : `Jack is 28 years old and he has an available balance of ₦100,000.`

# %%
name = "Jack"
age = 28
available_balance = 100000

print(f"{name} is {age} years old and he has an available balance of ₦{available_balance:,}.")
# Out:
# Jack is 28 years old and he has an available balance of ₦100,000.
