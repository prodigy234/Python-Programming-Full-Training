# %% [markdown]
# # 📘 Comprehensive Guide to Pandas `read_excel()`
# ### Instructor Notes for Teaching (Beginner → Advanced)
# **Generated on:** 03 March 2026
#
# ---
# ## 📌 Learning Objectives
# By the end of this lesson, students will:
# - Understand how to read Excel files using Pandas
# - Work with multiple sheets in a single Excel file
# - Handle messy Excel files (headers, skiprows, missing values)
# - Load specific columns and data types
# - Combine multiple sheets
# - Handle large Excel files efficiently

# %%
# Install openpyxl if not installed (Excel engine)
# !pip install openpyxl

import pandas as pd

# %% [markdown]
# ---
# # 1️⃣ Basic Usage of read_excel()
#
# ## Syntax:
# `pd.read_excel(io, sheet_name=0)`

# %%
# Read first sheet (default)
df = pd.read_excel('sample.xlsx')
df.head()
# Out:
#   OrderID    Customer Region  Product  Quantity  UnitPrice  OrderDate
# 0  ORD001  Customer_1   East    Phone         7        420 2025-09-11
# 1  ORD002  Customer_2   East    Phone         1        712 2025-10-23
# 2  ORD003  Customer_3  South  Monitor         8        642 2025-11-04
# 3  ORD004  Customer_4   West  Monitor         6        458 2025-04-21
# 4  ORD005  Customer_5   West    Phone         7       1384 2025-12-02

# %% [markdown]
# ---
# # 2️⃣ Reading a Specific Sheet
#
# You can specify sheet by:
# - Sheet index (0,1,2...)
# - Sheet name ("Sales", "Finance")

# %%
# By index
df1 = pd.read_excel('sample.xlsx', sheet_name=1)

# By sheet name
df2 = pd.read_excel('sample.xlsx', sheet_name='Sales')

df2.head()
# Out:
#   OrderID    Customer Region  Product  Quantity  UnitPrice  OrderDate
# 0  ORD001  Customer_1   East    Phone         7        420 2025-09-11
# 1  ORD002  Customer_2   East    Phone         1        712 2025-10-23
# 2  ORD003  Customer_3  South  Monitor         8        642 2025-11-04
# 3  ORD004  Customer_4   West  Monitor         6        458 2025-04-21
# 4  ORD005  Customer_5   West    Phone         7       1384 2025-12-02

# %% [markdown]
# ---
# # 3️⃣ Reading Multiple Sheets at Once
#
# To load ALL sheets:

# %%
all_sheets = pd.read_excel('sample.xlsx', sheet_name=None)

# all_sheets becomes a dictionary
print(type(all_sheets))

# Access individual sheet
all_sheets['Sales'].head()
# Out:
# <class 'dict'>
#   OrderID    Customer Region  Product  Quantity  UnitPrice  OrderDate
# 0  ORD001  Customer_1   East    Phone         7        420 2025-09-11
# 1  ORD002  Customer_2   East    Phone         1        712 2025-10-23
# 2  ORD003  Customer_3  South  Monitor         8        642 2025-11-04
# 3  ORD004  Customer_4   West  Monitor         6        458 2025-04-21
# 4  ORD005  Customer_5   West    Phone         7       1384 2025-12-02

# %% [markdown]
# ### Combine Multiple Sheets

# %%
combined_df = pd.concat(all_sheets.values(), ignore_index=True)
combined_df.head()
# Out:
#   OrderID    Customer Region  Product  Quantity  UnitPrice  OrderDate  \
# 0  ORD001  Customer_1   East    Phone       7.0      420.0 2025-09-11
# 1  ORD002  Customer_2   East    Phone       1.0      712.0 2025-10-23
# 2  ORD003  Customer_3  South  Monitor       8.0      642.0 2025-11-04
# 3  ORD004  Customer_4   West  Monitor       6.0      458.0 2025-04-21
# 4  ORD005  Customer_5   West    Phone       7.0     1384.0 2025-12-02
#
#   TransactionID Department ExpenseType  Amount TransactionDate PatientID  Age  \
# 0           NaN        NaN         NaN     NaN             NaT       NaN  NaN
# 1           NaN        NaN         NaN     NaN             NaT       NaN  NaN
# 2           NaN        NaN         NaN     NaN             NaT       NaN  NaN
# 3           NaN        NaN         NaN     NaN             NaT       NaN  NaN
# 4           NaN        NaN         NaN     NaN             NaT       NaN  NaN
#
#   Gender Diagnosis AdmissionDate DischargeDate
# ...

# %% [markdown]
# ---
# # 4️⃣ Working with Headers

# %%
# If header is on row 3
df = pd.read_excel('sample.xlsx', header=2)

# No header in file
df = pd.read_excel('sample.xlsx', header=None)

# Rename columns manually
df.columns = ['Col1', 'Col2', 'Col3']
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 8
#       5 df = pd.read_excel('sample.xlsx', header=None)
#       7 # Rename columns manually
# ----> 8 df.columns = ['Col1', 'Col2', 'Col3']
#       9 df.head()
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:6332, in NDFrame.__setattr__(self, name, value)
#    6330 try:
#    6331     object.__getattribute__(self, name)
# -> 6332     return object.__setattr__(self, name, value)
#    6333 except AttributeError:
#    6334     pass
#
# File pandas/_libs/properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:814, in NDFrame._set_axis(self, axis, labels)
#     809 """
# ...

# %% [markdown]
# ---
# # 5️⃣ Skipping Rows

# %%
# Skip first 2 rows
df = pd.read_excel('sample.xlsx', skiprows=2)

# Skip specific rows
df = pd.read_excel('sample.xlsx', skiprows=[0,2,4])
df.head()

# %% [markdown]
# ---
# # 6️⃣ Selecting Specific Columns

# %%
# Select by column names
df = pd.read_excel('sample.xlsx', usecols=['Name', 'Sales'])

# Select by column letters
df = pd.read_excel('sample.xlsx', usecols='A:C')
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Select by column names
# ----> 2 df = pd.read_excel('sample.xlsx', usecols=['Name', 'Sales'])
#       4 # Select by column letters
#       5 df = pd.read_excel('sample.xlsx', usecols='A:C')
#
# NameError: name 'pd' is not defined

# %% [markdown]
# ---
# # 7️⃣ Handling Missing Values

# %%
# Define custom missing values
df = pd.read_excel('sample.xlsx', na_values=['N/A', 'Missing'])
df.isna().sum()

# %% [markdown]
# ---
# # 8️⃣ Setting Data Types

# %%
df = pd.read_excel('sample.xlsx', dtype={'Sales': float, 'Age': int})
df.dtypes

# %% [markdown]
# ---
# # 9️⃣ Working with Dates

# %%
df = pd.read_excel('sample.xlsx', parse_dates=['Order_Date'])
df.info()

# %% [markdown]
# ---
# # 🔟 Reading Large Excel Files Efficiently
# - Load only required columns
# - Load specific sheets
# - Use nrows to limit rows

# %%
df = pd.read_excel('sample.xlsx', nrows=1000)
df.head()

# %% [markdown]
# ---
# # 🎯 Practical Teaching Exercises
# 1. Load only Finance sheet.
# 2. Skip first 3 rows and set header correctly.
# 3. Load all sheets and combine.
# 4. Load only columns A to D.
# 5. Convert Date column to datetime.
#
# ---
# # ✅ Summary
# `read_excel()` is extremely powerful and flexible for real-world Excel datasets.
# Mastering sheet handling, column selection, and messy data cleaning makes students industry-ready.
