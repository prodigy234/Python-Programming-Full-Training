# %% [markdown]
# # Python Core Programming: Comprehensive Questions, Answers and Line-by-Line Breakdown
#
# ## Kajola Gbenga
# ### Data Scientist & AI Engineer
#
# This notebook is a comprehensive practical guide to core Python programming concepts:
#
# 1. Lists
# 2. Strings
# 3. Tuples
# 4. Sets
# 5. Dictionaries
# 6. if, elif and else
# 7. Functions
# 8. for loops
# 9. while loops
# 10. break, continue and pass
# 11. Combining concepts in practical problems
#
# ### Learning approach
#
# Each major topic contains:
# - Concept explanations
# - Syntax
# - Practical questions
# - Complete answers
# - Line-by-line code breakdowns
# - Common mistakes
# - Practice exercises
# - Practical Data Science and AI connections
#
# > Note: Standard hyphens are used throughout this notebook.

# %% [markdown]
# # Table of Contents
#
# - [1. Python Lists](#1-python-lists)
# - [2. Python Strings](#2-python-strings)
# - [3. Python Tuples](#3-python-tuples)
# - [4. Python Sets](#4-python-sets)
# - [5. Python Dictionaries](#5-python-dictionaries)
# - [6. Conditional Statements](#6-conditional-statements)
# - [7. Functions](#7-functions)
# - [8. For Loops](#8-for-loops)
# - [9. While Loops](#9-while-loops)
# - [10. break, continue and pass](#10-break-continue-and-pass)
# - [11. Integrated Practical Questions](#11-integrated-practical-questions)
# - [12. Final Practice Section](#12-final-practice-section)

# %% [markdown]
# # 1. Python Lists
#
# A list is an ordered, mutable collection that can store multiple values.
#
# ```python
# students = ["Ada", "John", "Mary"]
# ```
#
# Important characteristics:
# - Ordered
# - Mutable
# - Allows duplicate values
# - Supports indexing and slicing
# - Can contain different data types

# %% [markdown]
# ## Question 1: Create and access a list
#
# Create a list of five student names and print the first and last student.

# %%
students = ["Ada", "John", "Mary", "David", "Grace"]

print(students[0])
print(students[-1])
# Out:
# Ada
# Grace

# %% [markdown]
# ### Line-by-line breakdown
#
# **Line 1:** `students = [...]`
# - Creates a variable called `students`.
# - The square brackets create a list.
# - Five strings are stored in the list.
#
# **Line 3:** `print(students[0])`
# - `students[0]` accesses the first item.
# - Python indexing starts from `0`.
#
# **Line 4:** `print(students[-1])`
# - `-1` means the last item in the list.
#
# Expected output:
# ```text
# Ada
# Grace
# ```

# %% [markdown]
# ## Question 2: Add, change and remove items
#
# Add a student, change one student's name and remove another student.

# %%
students = ["Ada", "John", "Mary"]

new_students = students.append("David")


print(new_students)
# Out:
# None

# %%
students = ["Ada", "John", "Mary"]

students.append("David")
students[1] = "James"
students.remove("Mary")

print(students)
# Out:
# ['Ada', 'James', 'David']

# %% [markdown]
# ### Line-by-line breakdown
#
# **Line 1:** Creates the original list.
#
# **Line 3:** `append()` adds one item to the end.
#
# **Line 4:** `students[1] = "James"` changes the second item.
#
# **Line 5:** `remove("Mary")` searches for and removes the value `"Mary"`.
#
# **Line 7:** Displays the final list.
#
# Final result:
# ```text
# ['Ada', 'James', 'David']
# ```

# %% [markdown]
# ## Question 3: Calculate total sales
#
# Given a list of sales, calculate the total and average sales.

# %%
sales = [15000, 22000, 18000, 25000, 30000]

total_sales = sum(sales)
average_sales = total_sales / len(sales)

print("Total sales:", total_sales)
print("Average sales:", average_sales)
# Out:
# Total sales: 110000
# Average sales: 22000.0

# %% [markdown]
# ### Line-by-line breakdown
#
# **Line 1:** Stores five sales values.
#
# **Line 3:** `sum(sales)` adds every value in the list.
#
# **Line 4:** `len(sales)` counts the number of sales. Dividing the total by that count gives the average.
#
# **Lines 6-7:** Display the calculated results.
#
# This pattern is very useful in Data Analytics.

# %% [markdown]
# ## Question 4: Filter passing scores
#
# Print `Pass` when a score is at least 50 and `Fail` otherwise.

# %%
scores = [45, 78, 32, 90, 55, 40]

for score in scores:
    if score >= 50:
        print(score, "Pass")
    else:
        print(score, "Fail")
# Out:
# 45 Fail
# 78 Pass
# 32 Fail
# 90 Pass
# 55 Pass
# 40 Fail

# %% [markdown]
# ### Line-by-line breakdown
#
# **Line 1:** Creates a list of scores.
#
# **Line 3:** The `for` loop takes one score at a time.
#
# **Line 4:** Tests whether the current score is greater than or equal to 50.
#
# **Line 5:** Runs when the condition is true.
#
# **Line 6:** Runs when the condition is false.
#
# The same structure is useful for classifying data into categories.

# %% [markdown]
# ## List methods you should know
#
# - `append()` - add one item
# - `extend()` - add multiple items
# - `insert()` - add at a specific position
# - `remove()` - remove a value
# - `pop()` - remove by position
# - `sort()` - sort the list
# - `reverse()` - reverse the list
# - `count()` - count occurrences
# - `index()` - find a value's position
# - `clear()` - remove all items

# %% [markdown]
# # 2. Python Strings
#
# A string is a sequence of characters enclosed in quotes.
#
# Examples:
# ```python
# name = "Kajola Gbenga"
# course = 'Python Programming'
# ```
#
# Strings are immutable, meaning an existing string cannot be changed in place.

# %% [markdown]
# ## Question 1: Extract characters
#
# Given a name, print the first character, last character and length.

# %%
name = "Kajola"

print(name[0])
print(name[-1])
print(len(name))
# Out:
# K
# a
# 6

# %% [markdown]
# ### Line-by-line breakdown
#
# **Line 1:** Stores `"Kajola"` in `name`.
#
# **Line 3:** Index `0` returns the first character.
#
# **Line 4:** Index `-1` returns the last character.
#
# **Line 5:** `len()` counts the characters.

# %% [markdown]
# ## Question 2: String methods
#
# Convert a name to uppercase, lowercase and title case.

# %%
name = "kajola gbenga"

print(name.upper())
print(name.lower())
print(name.title())
# Out:
# KAJOLA GBENGA
# kajola gbenga
# Kajola Gbenga

# %% [markdown]
# ### Line-by-line breakdown
#
# **Line 1:** Stores the name.
#
# **Line 3:** `.upper()` converts letters to uppercase.
#
# **Line 4:** `.lower()` converts letters to lowercase.
#
# **Line 5:** `.title()` capitalizes the first letter of each word.

# %% [markdown]
# ## Question 3: Split and join
#
# Separate a sentence into words and then combine the words with commas.

# %%
sentence = "Python is powerful"

words = sentence.split()
result = ", ".join(words)

print(words)
print(result)
# Out:
# ['Python', 'is', 'powerful']
# Python, is, powerful

# %% [markdown]
# ### Line-by-line breakdown
#
# **Line 1:** Stores the sentence.
#
# **Line 3:** `split()` breaks the sentence into a list using spaces.
#
# **Line 4:** `join()` combines the list items using `", "`.
#
# This is important for text preprocessing in NLP.

# %% [markdown]
# ## Question 4: Count a character
#
# Count how many times the letter `a` appears in a word.

# %%
word = "banana"

count_a = word.count("a")

print("Number of a characters:", count_a)
# Out:
# Number of a characters: 3

# %% [markdown]
# ### Line-by-line breakdown
#
# **Line 1:** Stores the word.
#
# **Line 3:** `count("a")` counts occurrences of `a`.
#
# **Line 5:** Prints the result.

# %% [markdown]
# # 3. Python Tuples
#
# A tuple is an ordered collection that cannot be changed after creation.
#
# ```python
# coordinates = (10, 20)
# ```
#
# Tuples are:
# - Ordered
# - Immutable
# - Allow duplicates
# - Indexable
# - Often used for fixed collections of values

# %% [markdown]
# ## Question 1: Create and access a tuple

# %%
employee = ("Gbenga", "Data Scientist", 5)

print(employee[0])
print(employee[1])
print(employee[2])
# Out:
# Gbenga
# Data Scientist
# 5

# %% [markdown]
# ### Line-by-line breakdown
#
# **Line 1:** Creates a tuple containing three values.
#
# **Lines 3-5:** Access the values using their indexes.
#
# Unlike lists, tuple items cannot be reassigned.

# %% [markdown]
# ## Question 2: Tuple unpacking

# %%
employee = ("Gbenga", "Data Scientist", 5)

name, role, experience = employee

print(name)
print(role)
print(experience)
# Out:
# Gbenga
# Data Scientist
# 5

# %% [markdown]
# ### Line-by-line breakdown
#
# **Line 1:** Creates a tuple.
#
# **Line 3:** Python unpacks the three tuple values into three variables.
#
# **Lines 5-7:** Prints each variable.
#
# Tuple unpacking is common when functions return multiple values.

# %% [markdown]
# ## Question 3: Why use a tuple?
#
# Suppose you have a fixed geographic coordinate. A tuple communicates that the values should remain fixed.

# %%
location = (6.5244, 3.3792)

latitude, longitude = location

print("Latitude:", latitude)
print("Longitude:", longitude)
# Out:
# Latitude: 6.5244
# Longitude: 3.3792

# %% [markdown]
# # 4. Python Sets
#
# A set is an unordered collection of unique values.
#
# Sets are especially useful for:
# - Removing duplicates
# - Membership testing
# - Union
# - Intersection
# - Difference

# %% [markdown]
# ## Question 1: Remove duplicates

# %%
numbers = [10, 20, 10, 30, 20, 40, 30]

unique_numbers = set(numbers)

print(unique_numbers)
# Out:
# {40, 10, 20, 30}

# %% [markdown]
# ### Line-by-line breakdown
#
# **Line 1:** Creates a list containing duplicate values.
#
# **Line 3:** `set(numbers)` converts the list into a set and automatically removes duplicates.
#
# **Line 5:** Displays the unique values.
#
# The order of a set should not be relied upon.

# %% [markdown]
# ## Question 2: Union and intersection

# %%
python_students = {"Ada", "John", "Mary"}
data_students = {"Mary", "David", "John"}

all_students = python_students.union(data_students)
both_courses = python_students.intersection(data_students)

print("All students:", all_students)
print("Students in both:", both_courses)
# Out:
# All students: {'Ada', 'John', 'Mary', 'David'}
# Students in both: {'John', 'Mary'}

# %% [markdown]
# ### Line-by-line breakdown
#
# **Lines 1-2:** Create two sets.
#
# **Line 4:** `union()` combines all unique values.
#
# **Line 5:** `intersection()` returns values found in both sets.
#
# This can be useful when comparing groups of customers, students or records.

# %% [markdown]
# ## Question 3: Difference

# %%
online_students = {"Ada", "John", "Mary"}
physical_students = {"John", "David"}

online_only = online_students.difference(physical_students)

print(online_only)
# Out:
# {'Ada', 'Mary'}

# %% [markdown]
# ### Line-by-line breakdown
#
# The `difference()` operation returns values present in the first set but not the second set.

# %% [markdown]
# # 5. Python Dictionaries
#
# A dictionary stores data as key-value pairs.
#
# ```python
# student = {
#     "name": "Ada",
#     "age": 20,
#     "score": 85
# }
# ```
#
# Dictionaries are heavily used in APIs, JSON, configuration files, data processing and machine learning workflows.

# %% [markdown]
# ## Question 1: Create and access a dictionary

# %%
student = {
    "name": "Ada",
    "age": 20,
    "score": 85
}

print(student["name"])
print(student["score"])
# Out:
# Ada
# 85

# %% [markdown]
# ### Line-by-line breakdown
#
# **Lines 1-5:** Create the dictionary.
#
# **Line 7:** Uses the key `"name"` to retrieve the student's name.
#
# **Line 8:** Uses the key `"score"` to retrieve the score.

# %% [markdown]
# ## Question 2: Add and update dictionary values

# %%
student = {
    "name": "Ada",
    "score": 85
}

student["age"] = 20
student["score"] = 90

print(student)
# Out:
# {'name': 'Ada', 'score': 90, 'age': 20}

# %% [markdown]
# ### Line-by-line breakdown
#
# **Line 7:** A new key `"age"` is created.
#
# **Line 8:** The existing `"score"` value is updated from 85 to 90.

# %% [markdown]
# ## Question 3: Loop through a dictionary

# %%
student = {
    "name": "Ada",
    "age": 20,
    "score": 90
}

for key, value in student.items():
    print(key, ":", value)
# Out:
# name : Ada
# age : 20
# score : 90

# %% [markdown]
# ### Line-by-line breakdown
#
# **Line 7:** `.items()` returns key-value pairs.
#
# **Line 7:** The loop unpacks each pair into `key` and `value`.
#
# **Line 8:** Prints each pair.
#
# This pattern is useful when inspecting structured data.

# %% [markdown]
# ## Question 4: Dictionary of multiple students

# %%
students = {
    "Ada": 85,
    "John": 72,
    "Mary": 45,
    "David": 90
}

for name, score in students.items():
    if score >= 50:
        print(name, "Pass")
    else:
        print(name, "Fail")
# Out:
# Ada Pass
# John Pass
# Mary Fail
# David Pass

# %% [markdown]
# ### Line-by-line breakdown
#
# **Lines 1-6:** Store student names as keys and scores as values.
#
# **Line 8:** Loop through each name and score.
#
# **Line 9:** Check whether the score is at least 50.
#
# **Line 10:** Print Pass for qualifying scores.
#
# **Line 12:** Print Fail for scores below 50.

# %% [markdown]
# # 6. Conditional Statements
#
# Conditional statements allow a program to make decisions.
#
# Basic structure:
#
# ```python
# if condition:
#     statement
# elif another_condition:
#     statement
# else:
#     statement
# ```

# %% [markdown]
# ## Question 1: Pass or fail

# %%
score = 67

if score >= 50:
    print("Pass")
else:
    print("Fail")
# Out:
# Pass

# %% [markdown]
# ### Line-by-line breakdown
#
# **Line 1:** Stores the score.
#
# **Line 3:** Tests whether the score is at least 50.
#
# **Line 4:** Executes when the condition is true.
#
# **Line 5:** Separates the alternative path.
#
# **Line 6:** Executes when the condition is false.

# %% [markdown]
# ## Question 2: Grade classification

# %%
score = 82

if score >= 70:
    grade = "A"
elif score >= 60:
    grade = "B"
elif score >= 50:
    grade = "C"
elif score >= 45:
    grade = "D"
else:
    grade = "F"

print("Grade:", grade)
# Out:
# Grade: A

# %% [markdown]
# ### Line-by-line breakdown
#
# Python evaluates the conditions from top to bottom.
#
# - 70 or above gets A.
# - 60 to 69 gets B.
# - 50 to 59 gets C.
# - 45 to 49 gets D.
# - Anything below 45 gets F.
#
# Once Python finds a true condition, it skips the remaining `elif` and `else` branches.

# %% [markdown]
# ## Question 3: Combine conditions

# %%
age = 25
has_id = True

if age >= 18 and has_id:
    print("Access granted")
else:
    print("Access denied")
# Out:
# Access granted

# %% [markdown]
# ### Line-by-line breakdown
#
# **Line 1:** Stores the person's age.
#
# **Line 2:** Stores a Boolean value.
#
# **Line 4:** `and` requires both conditions to be true.
#
# **Line 5:** Runs when both requirements are satisfied.
#
# **Line 7:** Runs otherwise.

# %% [markdown]
# # 7. Functions
#
# A function is a reusable block of code designed to perform a specific task.
#
# Basic syntax:
#
# ```python
# def function_name(parameters):
#     statements
#     return result
# ```

# %% [markdown]
# ## Question 1: Create a simple function

# %%
def greet():
    print("Welcome to Python")

greet()
# Out:
# Welcome to Python

# %% [markdown]
# ### Line-by-line breakdown
#
# **Line 1:** `def` tells Python that we are defining a function.
#
# **Line 2:** Contains the function body.
#
# **Line 4:** Calls the function.
#
# Defining a function does not execute it. The function runs when it is called.

# %% [markdown]
# ## Question 2: Function with a parameter

# %%
def greet_student(name):
    print("Welcome,", name)

greet_student("Ada")
greet_student("John")
# Out:
# Welcome, Ada
# Welcome, John

# %% [markdown]
# ### Line-by-line breakdown
#
# **Line 1:** Defines a function with a parameter called `name`.
#
# **Line 2:** Uses the parameter inside the function.
#
# **Line 4:** Calls the function and passes `"Ada"` as the argument.
#
# **Line 5:** Calls the same function with `"John"`.

# %% [markdown]
# ## Question 3: Function that returns a value

# %%
def calculate_total(price, quantity):
    total = price * quantity
    return total

result = calculate_total(2500, 4)

print("Total:", result)
# Out:
# Total: 10000

# %% [markdown]
# ### Line-by-line breakdown
#
# **Line 1:** Defines a function with two parameters.
#
# **Line 2:** Multiplies price by quantity.
#
# **Line 3:** Returns the calculated result.
#
# **Line 5:** Calls the function using 2500 and 4.
#
# **Line 7:** Displays the returned value.

# %% [markdown]
# ## Question 4: Function for data classification

# %%
def classify_score(score):
    if score >= 70:
        return "Excellent"
    elif score >= 50:
        return "Pass"
    else:
        return "Fail"

print(classify_score(82))
print(classify_score(55))
print(classify_score(30))
# Out:
# Excellent
# Pass
# Fail

# %% [markdown]
# ### Line-by-line breakdown
#
# The function receives a score and returns a category.
#
# The important idea is that the decision-making logic is packaged into a reusable function. This avoids repeating the same code throughout a program.

# %% [markdown]
# ## Question 5: Function with a default parameter

# %%
def calculate_discount(price, discount=10):
    discounted_price = price - (price * discount / 100)
    return discounted_price

print(calculate_discount(10000))
print(calculate_discount(10000, 20))
# Out:
# 9000.0
# 8000.0

# %% [markdown]
# ### Line-by-line breakdown
#
# **Line 1:** `discount=10` provides a default value.
#
# **Line 2:** Calculates the discount amount and subtracts it from the original price.
#
# **Line 5:** Uses the default 10 percent discount.
#
# **Line 6:** Overrides the default and uses 20 percent.

# %% [markdown]
# # 8. For Loops
#
# A `for` loop repeats code for each item in an iterable.
#
# Common iterables include:
# - Lists
# - Tuples
# - Strings
# - Sets
# - Dictionaries
# - `range()`

# %% [markdown]
# ## Question 1: Print numbers

# %%
for number in range(1, 6):
    print(number)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ### Line-by-line breakdown
#
# **Line 1:** `range(1, 6)` generates 1, 2, 3, 4 and 5.
#
# The ending value 6 is excluded.
#
# **Line 2:** Prints each number one at a time.

# %% [markdown]
# ## Question 2: Calculate total sales using a loop

# %%
sales = [10000, 15000, 12000, 18000]

total_sales = 0

for sale in sales:
    total_sales = total_sales + sale

print("Total sales:", total_sales)
# Out:
# Total sales: 55000

# %% [markdown]
# ### Line-by-line breakdown
#
# **Line 1:** Creates the sales list.
#
# **Line 3:** Starts the accumulator at zero.
#
# **Line 5:** Takes one sale at a time.
#
# **Line 6:** Adds the current sale to the running total.
#
# **Line 8:** Displays the final total.
#
# This is called an accumulator pattern.

# %% [markdown]
# ## Question 3: Count passing students

# %%
scores = [45, 78, 32, 90, 55, 40]

pass_count = 0

for score in scores:
    if score >= 50:
        pass_count = pass_count + 1

print("Number of passes:", pass_count)
# Out:
# Number of passes: 3

# %% [markdown]
# ### Line-by-line breakdown
#
# **Line 3:** Creates a counter starting at zero.
#
# **Line 5:** Examines each score.
#
# **Line 6:** Checks whether the score is at least 50.
#
# **Line 7:** Adds one whenever the student passes.
#
# This is a common data analysis pattern.

# %% [markdown]
# ## Question 4: Nested loop

# %%
departments = ["Data", "Finance"]
years = [2025, 2026]

for department in departments:
    for year in years:
        print(department, year)
# Out:
# Data 2025
# Data 2026
# Finance 2025
# Finance 2026

# %% [markdown]
# ### Line-by-line breakdown
#
# The outer loop selects a department.
#
# For every department selected, the inner loop runs through every year.
#
# This produces every department-year combination.

# %% [markdown]
# ## Question 5: Loop through a string

# %%
word = "Python"

for character in word:
    print(character)
# Out:
# P
# y
# t
# h
# o
# n

# %% [markdown]
# ### Line-by-line breakdown
#
# A string is iterable, so Python can process one character at a time.

# %% [markdown]
# ## Question 6: List comprehension
#
# Create a list containing the squares of numbers 1 through 5.

# %%
squares = [number ** 2 for number in range(1, 6)]

print(squares)
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# ### Line-by-line breakdown
#
# The expression means:
#
# 1. Generate numbers from 1 to 5.
# 2. Take each number.
# 3. Raise it to the power of 2.
# 4. Store the results in a new list.
#
# It is a compact alternative to a basic loop.

# %% [markdown]
# # 9. While Loops
#
# A `while` loop continues running as long as its condition remains true.
#
# Basic structure:
#
# ```python
# while condition:
#     statements
# ```

# %% [markdown]
# ## Question 1: Count from 1 to 5

# %%
number = 1

while number <= 5:
    print(number)
    number = number + 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ### Line-by-line breakdown
#
# **Line 1:** Starts the counter at 1.
#
# **Line 3:** Checks whether the counter is less than or equal to 5.
#
# **Line 4:** Prints the current value.
#
# **Line 5:** Increases the counter by 1.
#
# Without line 5, the loop could become infinite.

# %% [markdown]
# ## Question 2: User input with a while loop
#
# Keep asking for a score until the user enters 0.

# %%
total_sales = 0
sale = float(input("Enter sale amount, or 0 to stop: "))

while sale != 0:
    total_sales = total_sales + sale
    sale = float(input("Enter another sale, or 0 to stop: "))

print("Total sales:", total_sales)
# Out:
# Total sales: 37.0

# %% [markdown]
# ### Line-by-line breakdown
#
# **Line 1:** Requests the first score and converts the input from text to an integer.
#
# **Line 3:** Continues while the score is not zero.
#
# **Lines 4-7:** Classify the score.
#
# **Line 9:** Requests another score.
#
# **Line 11:** Executes after the user enters zero.
#
# This pattern is useful for interactive programs.

# %%
total_sales = 0

while True:
    sale = input("Enter sale amount, or 0 to stop: ")

    if sale == "":
        print("Please enter a number.")
        continue

    sale = float(sale)

    if sale == 0:
        break

    total_sales = total_sales + sale

print("Total sales:", total_sales)
# Out:
# Total sales: 12.0

# %% [markdown]
# Ask for a sale → validate the input → convert it to a number → check whether it is zero → add it to the total → repeat until zero is entered → display the final total.

# %% [markdown]
# ## Question 3: Total sales using repeated input

# %%
total_sales = 0
sale = float(input("Enter sale amount, or 0 to stop: "))

while sale != 0:
    total_sales = total_sales + sale
    sale = float(input("Enter another sale, or 0 to stop: "))

print("Total sales:", total_sales)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 2
#       1 total_sales = 0
# ----> 2 sale = float(input("Enter sale amount, or 0 to stop: "))
#       4 while sale != 0:
#       5     total_sales = total_sales + sale
#
# ValueError: could not convert string to float: ''

# %% [markdown]
# ### Line-by-line breakdown
#
# **Line 1:** Initializes the total.
#
# **Line 2:** Collects the first sale.
#
# **Line 4:** Continues until the user enters zero.
#
# **Line 5:** Adds each sale to the running total.
#
# **Line 6:** Requests the next sale.
#
# **Line 8:** Prints the final total.

# %% [markdown]
# # 10. break, continue and pass
#
# ## break
#
# Stops the loop immediately.
#
# ## continue
#
# Skips the current iteration and moves to the next iteration.
#
# ## pass
#
# Does nothing. It is commonly used as a placeholder.

# %% [markdown]
# ## Question 1: break
#
# Search for a number and stop when it is found.

# %%
numbers = [10, 20, 30, 50, 70, 90]

for number in numbers:
    if number == 50:
        print("Number found")
        break
    print(number)
# Out:
# 10
# 20
# 30
# Number found

# %% [markdown]
# ### Line-by-line breakdown
#
# The loop examines values in order.
#
# When `number == 50` becomes true, Python prints the message and immediately executes `break`, ending the loop.

# %% [markdown]
# ## Question 2: continue
#
# Print only even numbers.

# %%
numbers = [1, 2, 3, 4, 5, 6]

for number in numbers:
    if number % 2 != 0:
        continue
    print(number)
# Out:
# 2
# 4
# 6

# %% [markdown]
# ### Line-by-line breakdown
#
# **Line 4:** `%` calculates the remainder.
#
# If a number has a remainder when divided by 2, it is odd.
#
# **Line 5:** `continue` skips odd numbers.
#
# **Line 6:** Only even numbers reach the print statement.

# %% [markdown]
# ## Question 3: pass

# %%
age = 17

if age >= 18:
    pass
else:
    print("Under 18")
# Out:
# Under 18

# %% [markdown]
# ### Line-by-line breakdown
#
# `pass` allows Python to have an intentionally empty block. It does not produce output or change the program state.

# %% [markdown]
# # 11. Integrated Practical Questions
#
# This section combines lists, strings, dictionaries, sets, conditions, functions and loops.

# %% [markdown]
# ## Question 1: Student performance analyzer
#
# Create a function that receives student scores, calculates the average and classifies performance.

# %%
def analyze_scores(scores):
    total = 0

    for score in scores:
        total = total + score

    average = total / len(scores)

    if average >= 70:
        performance = "Excellent"
    elif average >= 50:
        performance = "Pass"
    else:
        performance = "Fail"

    return total, average, performance


scores = [75, 80, 65, 90, 70]

total, average, performance = analyze_scores(scores)

print("Total:", total)
print("Average:", average)
print("Performance:", performance)
# Out:
# Total: 380
# Average: 76.0
# Performance: Excellent

# %% [markdown]
# ### Detailed line-by-line breakdown
#
# **Line 1:** Defines the reusable function.
#
# **Line 2:** Creates an accumulator for the total.
#
# **Line 4:** Loops through every score.
#
# **Line 5:** Adds each score to the total.
#
# **Line 7:** Calculates the average.
#
# **Lines 9-15:** Classify the average using conditional statements.
#
# **Line 17:** Returns three values.
#
# **Line 20:** Creates the score list.
#
# **Line 22:** Calls the function.
#
# **Line 24:** Uses tuple unpacking to receive the three returned values.
#
# **Lines 26-28:** Display the results.
#
# This single example demonstrates functions, lists, loops, arithmetic, conditions and tuple unpacking.

# %% [markdown]
# ## Question 2: Remove duplicate names and count them
#
# Given a list of customer names, find the unique customers.

# %%
customers = [
    "Ada", "John", "Ada", "Mary",
    "John", "David", "Mary"
]

unique_customers = set(customers)

print("Original count:", len(customers))
print("Unique count:", len(unique_customers))
print("Unique customers:", unique_customers)
# Out:
# Original count: 7
# Unique count: 4
# Unique customers: {'John', 'David', 'Mary', 'Ada'}

# %% [markdown]
# ### Line-by-line breakdown
#
# The original list can contain duplicates.
#
# Converting it to a set removes duplicate values.
#
# `len(customers)` gives the number of records.
#
# `len(unique_customers)` gives the number of unique customers.
#
# This is directly related to duplicate detection in Data Analytics.

# %% [markdown]
# ## Question 3: Customer dictionary analysis
#
# Create a dictionary containing customer purchases and identify customers who spent at least 50,000.

# %%
purchases = {
    "Ada": 75000,
    "John": 32000,
    "Mary": 56000,
    "David": 42000
}

for customer, amount in purchases.items():
    if amount >= 50000:
        print(customer, "is a high-value customer")
    else:
        print(customer, "is a regular customer")
# Out:
# Ada is a high-value customer
# John is a regular customer
# Mary is a high-value customer
# David is a regular customer

# %% [markdown]
# ### Line-by-line breakdown
#
# The dictionary stores customer names and purchase amounts.
#
# The loop extracts each customer and amount.
#
# The conditional statement classifies customers based on their purchase amount.
#
# This resembles a basic customer segmentation workflow.

# %% [markdown]
# ## Question 4: Text analysis
#
# Count the number of words in a sentence and identify whether a target word exists.

# %%
sentence = "Python is powerful and Python is useful"
target = "Python"

words = sentence.split()
word_count = len(words)
target_count = words.count(target)

print("Number of words:", word_count)
print("Target word count:", target_count)

if target in words:
    print("Target word found")
else:
    print("Target word not found")
# Out:
# Number of words: 7
# Target word count: 2
# Target word found

# %% [markdown]
# ### Line-by-line breakdown
#
# **Line 1:** Stores the sentence.
#
# **Line 2:** Stores the target word.
#
# **Line 4:** Converts the sentence into a list of words.
#
# **Line 5:** Counts all words.
#
# **Line 6:** Counts occurrences of the target.
#
# **Lines 8-9:** Display the counts.
#
# **Line 11:** Uses membership testing to check whether the target exists.
#
# This is a foundation for NLP preprocessing.

# %% [markdown]
# ## Question 5: Simple sales report
#
# Use a list of dictionaries to represent sales records and calculate total revenue.

# %%
sales = [
    {"product": "Laptop", "quantity": 2, "price": 450000},
    {"product": "Phone", "quantity": 3, "price": 250000},
    {"product": "Tablet", "quantity": 4, "price": 180000}
]

total_revenue = 0

for sale in sales:
    revenue = sale["quantity"] * sale["price"]
    total_revenue = total_revenue + revenue
    print(sale["product"], "Revenue:", revenue)

print("Total revenue:", total_revenue)
# Out:
# Laptop Revenue: 900000
# Phone Revenue: 750000
# Tablet Revenue: 720000
# Total revenue: 2370000

# %% [markdown]
# ### Detailed line-by-line breakdown
#
# **Lines 1-5:** Create a list containing dictionaries. Each dictionary represents one sales transaction.
#
# **Line 7:** Initializes total revenue.
#
# **Line 9:** Loops through each transaction.
#
# **Line 10:** Retrieves quantity and price from the current dictionary and multiplies them.
#
# **Line 11:** Adds the transaction revenue to the running total.
#
# **Line 12:** Displays revenue for the current product.
#
# **Line 14:** Displays total revenue.
#
# This structure is very common when processing JSON-like business data.

# %% [markdown]
# # 12. Final Practice Section
#
# Try these yourself before looking at the solutions.
#
# ## Lists
#
# 1. Create a list of 10 numbers and calculate the largest number.
# 2. Calculate the smallest number.
# 3. Calculate the average.
# 4. Count how many numbers are greater than 50.
# 5. Reverse the list.
#
# ## Strings
#
# 6. Ask a user for their full name and print it in uppercase.
# 7. Count the number of characters.
# 8. Count the number of words.
# 9. Check whether the name contains the letter `a`.
# 10. Replace spaces with underscores.
#
# ## Tuples
#
# 11. Create a tuple containing a student's name, age and score.
# 12. Unpack the tuple.
# 13. Print each value.
# 14. Explain why a tuple may be preferred over a list for fixed information.
#
# ## Sets
#
# 15. Create two sets of course participants.
# 16. Find students in both courses.
# 17. Find students in only the first course.
# 18. Find all unique participants.
#
# ## Dictionaries
#
# 19. Create a dictionary for five employees and their salaries.
# 20. Loop through the dictionary.
# 21. Find employees earning at least 500,000.
# 22. Calculate the average salary.
#
# ## Conditions
#
# 23. Determine whether a number is positive, negative or zero.
# 24. Classify a student's grade.
# 25. Determine whether a person can vote based on age.
#
# ## Functions
#
# 26. Create a function that calculates the area of a rectangle.
# 27. Create a function that determines whether a number is even or odd.
# 28. Create a function that calculates a discounted price.
# 29. Create a function that calculates the average of a list.
#
# ## Loops
#
# 30. Print numbers from 1 to 100.
# 31. Print only even numbers from 1 to 100.
# 32. Calculate the sum of numbers from 1 to 100.
# 33. Find the largest number in a list without using `max()`.
# 34. Search for a specific value and stop using `break`.
#
# ## Integrated challenge
#
# 35. Build a simple student management program that:
# - Accepts student names and scores
# - Stores them in a dictionary
# - Uses a function to classify each score
# - Uses a loop to process every student
# - Calculates the class average
# - Reports the highest-performing student

# %% [markdown]
# # Quick Reference Cheat Sheet
#
# ## Lists
# ```python
# items = [1, 2, 3]
# items.append(4)
# items.remove(2)
# items[0]
# ```
#
# ## Strings
# ```python
# text.upper()
# text.lower()
# text.split()
# text.replace("a", "b")
# text.count("a")
# ```
#
# ## Tuples
# ```python
# data = (1, 2, 3)
# a, b, c = data
# ```
#
# ## Sets
# ```python
# a | b
# a & b
# a - b
# ```
#
# ## Dictionaries
# ```python
# data["key"]
# data.items()
# data.keys()
# data.values()
# ```
#
# ## Conditions
# ```python
# if condition:
#     ...
# elif condition:
#     ...
# else:
#     ...
# ```
#
# ## Functions
# ```python
# def function_name(parameter):
#     return result
# ```
#
# ## For loop
# ```python
# for item in items:
#     print(item)
# ```
#
# ## While loop
# ```python
# while condition:
#     ...
# ```
#
# ## Loop control
# ```python
# break
# continue
# pass
# ```

# %% [markdown]
# # Final Learning Summary
#
# By completing this notebook, you should be able to:
#
# - Create and manipulate Python lists
# - Process and transform strings
# - Use tuples for fixed collections
# - Remove duplicates and compare sets
# - Store structured information in dictionaries
# - Make decisions with `if`, `elif` and `else`
# - Build reusable functions
# - Iterate through data with `for` loops
# - Build condition-controlled programs with `while` loops
# - Control loops using `break`, `continue` and `pass`
# - Combine multiple Python concepts in practical business and Data Science problems
#
# The most important next step is practice. Do not only read the solutions. Attempt each question independently, make mistakes, debug them, and then compare your approach with the solution.
